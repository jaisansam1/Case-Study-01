# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the dataset to the python environment.

# %%
data = pd.read_csv('cars_data.csv')

# %% [markdown]
# # 2. Check for the null values present in the dataset.

# %%
data.head(5)
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  \
# 0  User-friendly   Belgium        Antwerpen        51.247239
# 1      analyzing     China            Jinhu        33.025433
# 2       software     China             Gemo        30.916207
# 3     monitoring  Portugal  Queluz de Baixo        38.745168
# 4       Sharable    Latvia         Jaunpils        56.729980
#
#    Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0          4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# 1        119.020584  Crimson    False    26/10/2015    51826.30    0.3147
# 2        121.677640    Khaki    False    28/03/2010    82929.14    0.5414
# 3         -9.267087     Puce    False    07/05/2008    56928.66    0.0850
# 4         23.016588   Yellow    False    01/06/2008    77201.26    0.1642
#
#    Resell Price  5-yr Depreciation  Top Speed  0-60 Time
# 0      33858.32               0.13      200.9       11.5
# 1       2989.28               0.02      158.5        8.8
# 2      35049.16               0.24      149.5       14.4
# 3       8236.15               0.20      153.3       11.5
# 4      32765.76               0.18      122.0       14.9

# %%
data.shape
data.ndim
# Out:
# 2

# %%
print(data.isnull().sum())
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %%
data['Buyer Gender'].value_counts()
# Out:
# Female    5052
# Male      4948
# Name: Buyer Gender, dtype: int64

# %%
print(data.dtypes)
# Out:
# Make                  object
# Model                 object
# Nickname              object
# Car Gender            object
# Buyer Gender          object
# Buyer Age              int64
# Buzzword              object
# Country               object
# City                  object
# Dealer Latitude      float64
# Dealer Longitude     float64
# Color                 object
# New Car                 bool
# Purchase Date         object
# Sale Price           float64
# Discount             float64
# Resell Price         float64
# 5-yr Depreciation    float64
# Top Speed            float64
# 0-60 Time            float64
# dtype: object

# %% [markdown]
# # 3. Plot a bar graph of male vs female buyers participated in the sales.

# %%
series = data["Buyer Gender"].value_counts()

series.plot(kind ='bar')
plt.show()

# %%
data[["Model", "Sale Price"]]
# Out:
#             Model  Sale Price
# 0          Vitara    54806.14
# 1           S2000    51826.30
# 2              Z4    82929.14
# 3          Tacoma    56928.66
# 4         Festiva    77201.26
# ...           ...         ...
# 9995      Tribute    58580.65
# 9996  Sierra 2500    75229.74
# 9997      Mariner    34755.44
# 9998      Leganza    98725.42
# 9999      Sequoia    96769.78
#
# [10000 rows x 2 columns]

# %% [markdown]
# # 4. Find the top 5 cars based on their sales price.

# %%
data = data.sort_values(
...     by="Sale Price",
...     ascending=False
... )
data[["Model", "Sale Price"]]
# Out:
#                      Model  Sale Price
# 5984             Jetta III    99997.65
# 1270                    A6    99991.91
# 3460                    LX    99983.38
# 9032                  MX-6    99978.17
# 302                     ES    99973.44
# ...                    ...         ...
# 6241  Continental Mark VII    10039.82
# 6270                 240SX    10024.86
# 5956                Mazda6    10023.85
# 7234             Excursion    10019.95
# 3513               Tracker    10003.76
#
# [10000 rows x 2 columns]

# %%
data[["Model", "Resell Price"]]
# Out:
#                      Model  Resell Price
# 5984             Jetta III      31601.95
# 1270                    A6      34711.19
# 3460                    LX      21462.44
# 9032                  MX-6      45958.19
# 302                     ES      32521.53
# ...                    ...           ...
# 6241  Continental Mark VII      10343.75
# 6270                 240SX      12695.97
# 5956                Mazda6      34125.80
# 7234             Excursion      22336.96
# 3513               Tracker      41226.94
#
# [10000 rows x 2 columns]

# %% [markdown]
# # 5. Find the least 5 cars based on their Resell price.

# %%
data = data.sort_values(
...     by="Resell Price",
...     ascending=True
... )
data[["Model", "Resell Price"]]
# Out:
#                Model  Resell Price
# 2446            1500       2000.84
# 4933     Savana 1500       2005.44
# 566               XF       2014.09
# 2538          3000GT       2017.24
# 5869             G37       2017.83
# ...              ...           ...
# 5173          Blazer      49981.31
# 2512     Sierra 2500      49984.39
# 222               TL      49988.65
# 8406  Econoline E350      49996.96
# 3224          Camaro      49997.05
#
# [10000 rows x 2 columns]
